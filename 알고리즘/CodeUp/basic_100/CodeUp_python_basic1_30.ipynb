# %%
# 6001
print("Hello")

# 6002
print("Hello World")

# 6003
print("Hello")
print("World")

# 6004
print("'Hello'")

# 6005
print('"Hello World"')

# 6006
print("\"!@#$%^&*()'")

# 6007
print("\"C:\\Download\\'hello'.py\"")

# 6008
print("print(\"Hello\\nWorld\")")

# 6009
c = input()
print(c)

# 6010
n = input()
n = int(n)
print(n)

# 6011
f = input()
f = float(f)
print(f)

# 6012
a = input() 
b = input()
print(a)
print(b)

# 6013
a = input() 
b = input()
print(b)
print(a)

# 6014
f = input()
print(f)
print(f)
print(f)

# 6015
a, b = input().split()
print(a)
print(b)

# 6016
a, b = input().split()
print(b)
print(a)

# 6017
s = input()
print(s, s, s)

# 6018
a, b = input().split(':')
print(a, b, sep=':')
# s = input()
# print(s)

# 6019
y, m, d = input().split('.')
print(f"{d}-{m}-{y}")

# 6020
a, b = input().split('-')
print(str(a)+str(b))

# 6021
s = input()
for i in s:print(i)

# 6022
s = input() # 200304 -> 20 03 04
for i in rnage(0,6,2):print(s[i:i+1])

# 6023
s = input().split(':') # 17:23:57 -> 23
print(s[1])

# 6024
w1, w2 = input().split()
s = w1 + w2
print(s)

# s = input() # hello world -> helloworld
# "".join(s.split()) # s.replace(" ","")

# 6025
a,b = input().split() # 123 -123 -> 0
print(int(a)+int(b))

# 6026
a = input() # 0.1
b = input() # 0.9
print(float(a)+float(b))

# 6027 - 10진수를 입력받아 16진수(hexadecimal)로 출력
a = int(input()) # 255 -> ff
print('%x'% a)  # 16진수(hexadecimal) 소문자 형태 문자열로 출력
# %o로 출력하면 8진수(octal) 문자열

# 6028
# n에 저장되어있는 값을 16진수 대문자 형태 문자열로 출력
n = int(input()) # 255 -> FF
print('%X' % n)

# 6029
# 16진수를 입력받아 8진수(octal)로 출력
a = int(input(), 16) # f -> 17
print('%o'% a)

# 6030
# 영문자 1개를 입력받아 10진수 유니코드(Unicode) 값으로 출력
s = ord(input()) # A -> 65
print(s)
# ord( ) 는 어떤 문자의 순서 위치(ordinal position) 값을 의미
